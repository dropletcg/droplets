# %% [markdown]
# [dropletcg](https://github.com/dropletcg) on Github
#
# [![заготовка](https://colab.research.google.com/assets/colab-badge.svg)](https://github.com/dropletcg/droplets/blob/main/16_09_23.ipynb) notebook

# %%
#@markdown #<font size="6"><font color="orange">**Setup WebUI**<br>

instant_replace = False #@param {type: "boolean"}
branch_name = 'master' #@param {type: "string"}
#@markdown ---
install_extension = True #@param {type: "boolean"}
install_ControlNet_model = True #@param {type: "boolean"}
#@markdown ---
import_model_from_drive = False #@param {type: "boolean"}
import time
import os
import json
from google.colab import drive, output
def join(d: str, l: list[str], *a:str):
    for x in a:
        l.append(x)
    return d.join(l)

def rd(l):
    return [*set(l)]

def wait(t):
    time.sleep(t)

def mount():
    c = True
    p = '/content/drive'
    if os.path.exists(p):
        c = False
    if c :
        drive.mount(p, force_remount=True)

def git_clone(repo, path):
    if path:
        # %cd {path}
    for x in repo:
        # !git clone {x}
    # %cd /content

def clear():
    output.clear()

def rm(path, arg = ''):
    if arg == '-r':
        os.removedirs(path)
    else:
        os.remove(path)

if import_model_from_drive:
   print('Please allow access to drive we will only save and read our service content')
   mount()

# %cd /content
# !apt-get -y install -qq aria2
# !pip install --upgrade fastapi
# !apt install libcairo2-dev pkg-config python3-dev
# !pip install svglib
# !pip install pytorch-lightning==1.6.5
# !pip install torchmetrics==0.11.0
# !pip install --upgrade huggingface_hub
# !pip install open-clip-torch==2.20.0
# !pip install pydantic==1.10.5
clear()
j = 'https://github.com/AUTOMATIC1111/stable-diffusion' + '-webui'
if instant_replace and os.path.exists('/content/project'):
  rm('/content/project', '-r')

# !git clone -b {branch_name} {j} /content/project
if install_extension:
   # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://raw.githubusercontent.com/dropletcg/droplets/main/extensions.txt
   install = open('/content/extensions.txt', 'r').read().split('\n')
   git_clone(install, '/content/project/extensions')
if install_ControlNet_model:
   print('\033[38;5;190mWait for install ControlNet Models\033[39m')
   p = '/content/project/extensions/sd-we' + 'bui-controlnet/models'
   # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://raw.githubusercontent.com/dropletcg/droplets/main/control_net_model.json -d /content
   o = json.load(open('/content/control_net_model.json', 'r'))
   for x in o:
        l = f"\"{x}\""
        # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {l} -o {o[x]} -d {p}

if import_model_from_drive:
   save_path =  '/content/drive/MyDrive/kimyobu-colab/models/'
   model_path = '/content/project/models/'
   # !mkdir -p {save_path}
   for x in os.listdir(save_path):
       fol = model_path + x.split('.')[0]
       # !mkdir -p {fol}
       # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M -i {save_path + x} -d {fol}

os.environ['setup'] = 'True'
clear()
print('\033[38;5;82m' + 'Setup WebUI Complete')

# %%
#@title #<font size="6"><font color="blue">◀-<font size="6"><font color="orange"> **Edit list** <font size="5"><font color="gray">(Models, Lora and other Components)
#@markdown default settings RPG v5
#!apt -y install -qq aria2
# !mkdir -p /content/project/models/Lora
# !mkdir -p /content/project/models/ESRGAN

# SDXL base
#!curl -Lo /content/project/models/Stable-diffusion/sd_xl_base_1.0_0.9vae.safetensors https://huggingface.co/ckpt/sd_xl_base_1.0/resolve/main/sd_xl_base_1.0_0.9vae.safetensors
#!curl -Lo /content/project/models/Stable-diffusion/sd_xl_refiner_1.0_0.9vae.safetensors https://huggingface.co/ckpt/sd_xl_refiner_1.0/resolve/main/sd_xl_refiner_1.0_0.9vae.safetensors
#!curl -Lo /content/project/models/Lora/sd_xl_offset_example-lora_1.0.safetensors https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors

# Models SDXL
# Cinemax Alpha | SDXL | Cinema | Filmic | NSFW & LoRA MovieStillXL
#!curl -Lo /content/project/models/Stable-diffusion/cinemaxAlphaSDXLCinema_alpha1.safetensors https://civitai.com/api/download/models/144968
#!curl -Lo /content/project/models/Lora/MovieStillXLV7.safetensors https://civitai.com/api/download/models/135512
# Juggernaut XL v.2 & Juggernaut Cinematic XL LoRA
#!curl -Lo /content/project/models/Stable-diffusion/juggernautXL_version2.safetensors https://civitai.com/api/download/models/152076
#!curl -Lo /content/project/models/Lora/JuggerCineXL2.safetensors https://civitai.com/api/download/models/131991
# ZavyChromaXL
#!curl -Lo /content/project/models/Stable-diffusion/zavychromaxl_v10.safetensors https://civitai.com/api/download/models/149243
# RealVisXL V1.0 https://civitai.com/models/139562/realvisxl-v10
#!curl -Lo /content/project/models/Stable-diffusion/realvisxlV10_v10VAE.safetensors https://civitai.com/api/download/models/149243

# LoRAs SDXL
# Cyborg Style SDXL
#!curl -Lo /content/project/models/Lora/cyborg_style_xl-alpha.safetensors https://civitai.com/api/download/models/154590


# Models SD 1.5
# rpg_v5 https://civitai.com/models/1116?modelVersionId=124626
# !curl -Lo /content/project/models/Stable-diffusion/rpg_v5.safetensors https://civitai.com/api/download/models/124626
# epiCRealism https://civitai.com/models/25694/epicrealism
#!curl -Lo /content/project/models/Stable-diffusion/epicrealism_naturalSinRC1VAE.safetensors https://civitai.com/api/download/models/143906
# Photon https://civitai.com/models/84728?modelVersionId=90072
#!curl -Lo /content/project/models/Stable-diffusion/photon_v1.safetensors https://civitai.com/api/download/models/90072?type=Model&format=SafeTensor&size=pruned&fp=fp16
# Realistic Vision V5.1
#!curl -Lo /content/project/models/Stable-diffusion/realisticVisionV51_v51VAE.safetensors https://civitai.com/api/download/models/130072
#!curl -Lo /content/project/models/Stable-diffusion/realisticVisionV51_v51VAE-inpainting.safetensors https://civitai.com/api/download/models/130090
# Juggernaut aftermath https://civitai.com/models/46422?modelVersionId=127207
#!curl -Lo /content/project/models/Stable-diffusion/juggernaut_aftermath.safetensors https://civitai.com/api/download/models/127207?type=Model&format=SafeTensor&size=full&fp=fp32
#!curl -Lo /content/project/models/Stable-diffusion/juggernaut_aftermath-inpainting.safetensors https://civitai.com/api/download/models/129549?type=Model&format=SafeTensor&size=full&fp=fp32
#!curl -Lo /content/project/models/VAE/TRCVAE.safetensors https://civitai.com/api/download/models/127207?type=VAE&format=SafeTensor
# Juggernaut Final https://civitai.com/models/46422?modelVersionId=114770
#!curl -Lo /content/project/models/Stable-diffusion/juggernaut_final.safetensors https://civitai.com/api/download/models/114770?type=Model&format=SafeTensor&size=full&fp=fp32
#!curl -Lo /content/project/models/VAE/juggernaut_finalBakedVAE.safetensors https://civitai.com/api/download/models/117037?type=Model&format=SafeTensor&size=full&fp=fp32
#!curl -Lo /content/project/models/Stable-diffusion/juggernaut_final-inpainting.safetensors https://civitai.com/api/download/models/116127?type=Model&format=SafeTensor&size=full&fp=fp32
# AbsoluteReality https://civitai.com/models/81458?modelVersionId=132760
#!curl -Lo /content/project/models/Stable-diffusion/absolutereality_v181.safetensors https://civitai.com/api/download/models/132760?type=Model&format=SafeTensor&size=pruned&fp=fp16
#!curl -Lo /content/project/models/Stable-diffusion/absolutereality_v181INPAINTING.safetensors https://civitai.com/api/download/models/134084?type=Model&format=SafeTensor&size=full&fp=fp32
# DELIBERATE v3 https://civitai.com/models/4823/deliberate
#!curl -Lo /content/project/models/Stable-diffusion/deliberate_v3.safetensors https://civitai.com/api/download/models/156110?type=Model&format=SafeTensor&size=full&fp=fp16
#!curl -Lo /content/project/models/Stable-diffusion/deliberate_v3-inpainting.safetensors https://civitai.com/api/download/models/156106?type=Model&format=SafeTensor&size=full&fp=fp16

# LoRAs
# CinematicStyleV1 (Trigger Words - 111cine8matic55) https://civitai.com/models/101844/cinematicstylev1
# !curl -Lo /content/project/models/Lora/CineStyle5.safetensors https://civitai.com/api/download/models/109018
# Anamorphic Lens Flare (Trigger Words - Lens flare) https://civitai.com/models/62004/anamorphic-lens-flare
# !curl -Lo /content/project/models/Lora/Anamorphic_lens_flare.safetensors https://civitai.com/api/download/models/66522?type=Model&format=SafeTensor
# epiCRealismHelper
#!curl -Lo /content/project/models/Lora/epiCRealismHelper.safetensors https://civitai.com/api/download/models/118945
# Detail Tweaker
# !curl -Lo /content/project/models/Lora/detailtweaker.safetensors https://huggingface.co/nolanaatama/dtltwkr/resolve/main/dtltwkr.safetensors
# LowRA
#!curl -Lo /content/project/models/Lora/LowRA.safetensors https://civitai.com/api/download/models/63006
# epi_noiseoffset
# !curl -Lo /content/project/models/Lora/epi_noiseoffset2.safetensors https://civitai.com/api/download/models/16576?type=Model&format=SafeTensor&size=full&fp=fp16
# Urban Samurai (Trigger Words - techwear jacket, black gloves, tactical vest, with buckle and tape)
# !curl -Lo /content/project/models/Lora/urbansamurai_v0.3.safetensors https://civitai.com/api/download/models/27871?type=Model&format=SafeTensor&size=full&fp=fp16
# Urban Techwear (Trigger Words - urban techwear,outfit)
# !curl -Lo /content/project/models/Lora/urbantechwear.safetensors https://civitai.com/api/download/models/121783
# Eyes (Trigger Words - perfect eyes,perfect skin,detailed skin) https://civitai.com/models/116247/eyes-female-from-polyhedron
#!curl -Lo /content/project/models/Lora/polyhedron_all_eyes.safetensors https://civitai.com/api/download/models/127908
# Alicia Vikander (Trigger Words - sks woman) https://civitai.com/models/86785?modelVersionId=92310
#!curl -Lo /content/project/models/Lora/locon_aliciavikander_v1_from_v1_64_32.safetensors https://civitai.com/api/download/models/92310
# LEOSAM's Clothing +/- Adjuster https://civitai.com/models/88132/leosams-clothing-adjuster-lora
#!curl -Lo /content/project/models/Lora/ClothingAdjuster3.safetensors https://civitai.com/api/download/models/117151?type=Model&format=SafeTensor

# ??????? HYPERNETWORK
# Latent Layer Cameras https://civitai.com/models/140117/latent-layer-cameras (tutor - https://www.youtube.com/watch?v=JB-BmFUdT7o)
#curl -Lo /content/project/models/hypernetworks/. . .  https://civitai.com/api/download/models/155236

# Upscalers
# !curl -Lo /content/project/models/ESRGAN/4x-UltraSharp.pth https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth

# VAE
# !curl -Lo /content/project/models/VAE/vae-ft-mse-840000-ema-pruned.ckpt https://huggingface.co/YANGYINGDUO/vae-ft-mse-840000-ema-pruned.ckpt/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt

# embeddings
# !curl -Lo /content/project/embeddings/BadDream.pt https://civitai.com/api/download/models/77169?type=Model&format=PickleTensor
# !curl -Lo /content/project/embeddings/UnrealisticDream.pt https://civitai.com/api/download/models/77173?type=Model&format=PickleTensor
# !curl -Lo /content/project/embeddings/epiCNegative.pt https://civitai.com/api/download/models/95263?type=Model&format=Other
# !curl -Lo /content/project/embeddings/EasyNegative.pt https://huggingface.co/embed/negative/resolve/main/EasyNegative.pt
# !curl -Lo /content/project/embeddings/EasyNegativeV2.safetensors https://huggingface.co/embed/negative/resolve/main/EasyNegativeV2.safetensors
# !curl -Lo /content/project/embeddings/bad-artist.pt https://huggingface.co/embed/negative/resolve/main/bad-artist.pt
# !curl -Lo /content/project/embeddings/bad-hands-5.pt https://huggingface.co/embed/negative/resolve/main/bad-hands-5.pt
# !curl -Lo /content/project/embeddings/bad-image-v2-39000.pt https://huggingface.co/embed/negative/resolve/main/bad-image-v2-39000.pt
# !curl -Lo /content/project/embeddings/bad_prompt_version2.pt https://huggingface.co/embed/negative/resolve/main/bad_prompt_version2.pt
# !curl -Lo /content/project/embeddings/ng_deepnegative_v1_75t.pt https://huggingface.co/embed/negative/resolve/main/ng_deepnegative_v1_75t.pt
# !curl -Lo /content/project/embeddings/verybadimagenegative_v1.3.pt https://huggingface.co/embed/negative/resolve/main/verybadimagenegative_v1.3.pt

clear()
print('\033[38;5;82m' + 'Setup Components Complete')

# %%
#@markdown #<font size="6"><font color="orange">**Launch WebUI**
import os
if not os.environ.get('setup'):
    raise SystemExit('\033[31mRun SetUP WebUI FIRST!!\033[39m')
# %cd /content/project

save_to_drive = False #@param {type: "boolean"}
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://raw.githubusercontent.com/Kimyobu/Stable-diffusion-a1111-colab/main/styles.csv
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://raw.githubusercontent.com/dropletcg/droplets/main/styles.csv
if save_to_drive:
   mount()
   # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://raw.githubusercontent.com/dropletcg/droplets/main/config.json
   #!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://raw.githubusercontent.com/Kimyobu/Stable-diffusion-a1111-colab/main/SD/config.json

clear()
# Web UI tunnel
args = "--share --no-half-vae --xformers --enable-insecure-extension- --theme dark" #@param {type:"string"}
args = f"\"{args}\""
# !COMMANDLINE_ARGS={args} REQS_FILE="requirements.txt" python launch.py
